# %% [markdown]
# # Final Project

# %%
import random
import pandas as pd
from gurobipy import *

# %%
def get_d(e, s, F):
    coverage = sum(F.loc[e,s])
    return min(1, coverage)

# %%
def get_s(nodes, sensors):
    sigma_s = random.sample(nodes, sensors)
    return(sigma_s)

# %%
def get_random_I(I_length, n_nodes, n_sensors):
    nodes_indexes = [i for i in range(n_nodes)]
    I = []

    for _ in range(I_length):
        sigma_s = get_s(nodes_indexes, n_sensors)
        if sigma_s not in I:
            I.append(sigma_s)
        
    return I

# %%
def run_RMP(params):
    model = Model("Model")
    model.Params.LogToConsole = 0

    z = model.addVar( name="z")
    sigmas = [model.addVar(name = "s_" + str(s)) for s in range(params["I"]["length"])]

    model.setObjective(z, GRB.MAXIMIZE)

    for e in range(params["n_pipes"]):
        model.addConstr(
            z <= sum(
                get_d(e, params["I"]["set"][s], params["F"]["matrix"])*sigmas[s]
                for s in range(params["I"]["length"])
            ),
            name  = "y_"+str(e)
        )

    model.addConstr(sum(sigmas) == 1, name = "w")
    model.optimize();
    
    return model

# %%
def get_params(n_sensors, n_nodes, n_pipes, I, F):
    return {
        "F" : {
            "n_rows" : F.shape[1],
            "n_columns" : F.shape[0],
            "matrix" : F
        },
        "I" : {
            "length" : len(I),
            "set" : I
        },
        "n_nodes": n_nodes,
        "n_sensors": n_sensors,
        "n_pipes" : n_pipes
    }

# %%
def update_I(params, s):
    params["I"]["set"].append(s)
    params["I"]["length"] += 1

# %%
def get_dual_variables(model):
    dual_vars = model.getConstrs()
    len_dual = len(dual_vars)
    return {
        "Y" : [y.Pi for y in dual_vars[0:len_dual-1]],
        "w" : dual_vars[len_dual-1].Pi
    }

# %%
def run_PrincingP(dual_vars, params):
    model = Model("Model")
    model.Params.LogToConsole = 0

    P = [model.addVar(name = "P_" + str(e)) for e in range(params["n_pipes"])]
    X = [model.addVar(vtype=GRB.BINARY, name = "X_" + str(v)) for v in range(params["n_nodes"])]

    model.setObjective(sum(P[e]*dual_vars["Y"][e] for e in range(params["n_pipes"])), GRB.MAXIMIZE)
    model.addConstr(sum(X) == params["n_sensors"])
    
    for e in range(params["n_pipes"]):
        model.addConstr(
            P[e] <= sum(
                params["F"]["matrix"].loc[e, v]*X[v]
                for v in range(params["n_nodes"])
            ),
            name = "y_"+str(e)
        )
        model.addConstr(P[e] <= 1)

    model.optimize();
    X_values = [x.x for x in X]
    new_s = [i for i in range(len(X_values)) if X_values[i] > 0]

    return model.ObjVal, new_s

# %%
def get_dataframe():
    return pd.DataFrame(data = {
        'ObjValue' : [],
        'ReducedCost' : []
    })

# %%
def update_results(RMproblem, cost, results):
    results.loc[len(results)] = [
        RMproblem.ObjVal,
        cost
    ]
    return results

# %%
def get_prob_distribution(params, RMproblem, results):
    I = pd.DataFrame(data = params["I"]["set"])
    I.columns = ["Sensor_"+str(i) for i in range(1,params["n_sensors"]+1)]

    dist = RMproblem.getVars()
    I["Prob"] = [x.x for x in dist[1:len(dist)]]

    I.to_csv("ProbDist"+str(params["n_sensors"])+".csv", sep=',')

# %% [markdown]
# -----------------------------
# ## Main

# %%
def run(params, results):
    is_optimal = False
    counter = 0

    while is_optimal == False:
        counter +=1
        RMproblem = run_RMP(params)

        dual_vars = get_dual_variables(RMproblem)
        cost, s = run_PrincingP(dual_vars, params)

        results = update_results(RMproblem, cost, results)

        if cost - dual_vars["w"] <= 0:
            get_prob_distribution(params, RMproblem, results)
            results.to_csv("ObjVal"+str(params["n_sensors"])+".csv", sep = ",")
            is_optimal = True
        else:
            update_I(params, s)

        print("Iteration number " +str(counter)+ " complete")
        print("Objective Value: "+str(RMproblem.ObjVal))

# %%
n_nodes = 811
n_pipes = 1123
n_sensors = 7

I = [[i for i in range(n_sensors)]]

F = pd.read_csv(
    'Detection_Matrix.csv',
    names = [x for x in range(n_nodes)]
)

# %%
params = get_params(n_sensors, n_nodes, n_pipes, I, F)
results = get_dataframe()

results = run(params, results)
# Out:
# Iteration number 1 complete
# Objective Value: -0.0
# Iteration number 2 complete
# Objective Value: -0.0
# Iteration number 3 complete
# Objective Value: -0.0
# Iteration number 4 complete
# Objective Value: -0.0
# Iteration number 5 complete
# Objective Value: -0.0
# Iteration number 6 complete
# Objective Value: -0.0
# Iteration number 7 complete
# Objective Value: -0.0
# Iteration number 8 complete
# Objective Value: -0.0
# Iteration number 9 complete
# Objective Value: -0.0
# Iteration number 10 complete
# Objective Value: -0.0
# Iteration number 11 complete
# Objective Value: -0.0
# Iteration number 12 complete
# Objective Value: -0.0
# Iteration number 13 complete
# Objective Value: -0.0
# Iteration number 14 complete
# Objective Value: -0.0
# Iteration number 15 complete
# Objective Value: 0.07142857142857142
# Iteration number 16 complete
# Objective Value: 0.07692307692307693
# Iteration number 17 complete
# Objective Value: 0.09090909090909091
# Iteration number 18 complete
# Objective Value: 0.125
# Iteration number 19 complete
# Objective Value: 0.14285714285714285
# Iteration number 20 complete
# Objective Value: 0.14285714285714288
# Iteration number 21 complete
# Objective Value: 0.16666666666666666
# Iteration number 22 complete
# Objective Value: 0.2
# Iteration number 23 complete
# Objective Value: 0.20833333333333334
# Iteration number 24 complete
# Objective Value: 0.23076923076923078
# Iteration number 25 complete
# Objective Value: 0.23076923076923078
# Iteration number 26 complete
# Objective Value: 0.23076923076923078
# Iteration number 27 complete
# Objective Value: 0.23076923076923073
# Iteration number 28 complete
# Objective Value: 0.23333333333333334
# Iteration number 29 complete
# Objective Value: 0.24344569288389514
# Iteration number 30 complete
# Objective Value: 0.24950884086444008
# Iteration number 31 complete
# Objective Value: 0.2542812662169175
# Iteration number 32 complete
# Objective Value: 0.257
# Iteration number 33 complete
# Objective Value: 0.2684563758389262
# Iteration number 34 complete
# Objective Value: 0.2708228167592125
# Iteration number 35 complete
# Objective Value: 0.2742857142857143
# Iteration number 36 complete
# Objective Value: 0.27764005949429843
# Iteration number 37 complete
# Objective Value: 0.28016359918200406
# Iteration number 38 complete
# Objective Value: 0.28159392789373805
# Iteration number 39 complete
# Objective Value: 0.28727329519942213
# Iteration number 40 complete
# Objective Value: 0.2919554417184868
# Iteration number 41 complete
# Objective Value: 0.2958760092057637
# Iteration number 42 complete
# Objective Value: 0.30031737885890963
# Iteration number 43 complete
# Objective Value: 0.30477683949253703
# Iteration number 44 complete
# Objective Value: 0.3059229628554245
# Iteration number 45 complete
# Objective Value: 0.3081021687220316
# Iteration number 46 complete
# Objective Value: 0.31264991276177134
# Iteration number 47 complete
# Objective Value: 0.313460413266406
# Iteration number 48 complete
# Objective Value: 0.3186447246274866
# Iteration number 49 complete
# Objective Value: 0.3204650938740869
# Iteration number 50 complete
# Objective Value: 0.32096233865719437
# Iteration number 51 complete
# Objective Value: 0.3239067725796113
# Iteration number 52 complete
# Objective Value: 0.32632261501424153
# Iteration number 53 complete
# Objective Value: 0.32813742524919
# Iteration number 54 complete
# Objective Value: 0.3290801097936355
# Iteration number 55 complete
# Objective Value: 0.33159490826875776
# Iteration number 56 complete
# Objective Value: 0.33359859390470187
# Iteration number 57 complete
# Objective Value: 0.33493068029631995
# Iteration number 58 complete
# Objective Value: 0.3371436809178281
# Iteration number 59 complete
# Objective Value: 0.3371810807246838
# Iteration number 60 complete
# Objective Value: 0.3382111676089628
# Iteration number 61 complete
# Objective Value: 0.33924406726713346
# Iteration number 62 complete
# Objective Value: 0.3419191090031765
# Iteration number 63 complete
# Objective Value: 0.34302813486556016
# Iteration number 64 complete
# Objective Value: 0.3469043691492618
# Iteration number 65 complete
# Objective Value: 0.3491166125585009
# Iteration number 66 complete
# Objective Value: 0.350071450608637
# Iteration number 67 complete
# Objective Value: 0.35194649570687686
# Iteration number 68 complete
# Objective Value: 0.35291568218178837
# Iteration number 69 complete
# Objective Value: 0.35461382452129697
# Iteration number 70 complete
# Objective Value: 0.35551646047186164
# Iteration number 71 complete
# Objective Value: 0.35660496890964416
# Iteration number 72 complete
# Objective Value: 0.3573742167627409
# Iteration number 73 complete
# Objective Value: 0.35741371284128903
# Iteration number 74 complete
# Objective Value: 0.35789276016375693
# Iteration number 75 complete
# Objective Value: 0.35853001839483384
# Iteration number 76 complete
# Objective Value: 0.35911378318580384
# Iteration number 77 complete
# Objective Value: 0.35930033958090474
# Iteration number 78 complete
# Objective Value: 0.35934200926193777
# Iteration number 79 complete
# Objective Value: 0.3602117512743405
# Iteration number 80 complete
# Objective Value: 0.3602973301143979
# Iteration number 81 complete
# Objective Value: 0.36050539736435594
# Iteration number 82 complete
# Objective Value: 0.36059931364506403
# Iteration number 83 complete
# Objective Value: 0.36086413036855297
# Iteration number 84 complete
# Objective Value: 0.3610933940083297
# Iteration number 85 complete
# Objective Value: 0.36135845591733456
# Iteration number 86 complete
# Objective Value: 0.36146312229609195
# Iteration number 87 complete
# Objective Value: 0.3614977968440393
# Iteration number 88 complete
# Objective Value: 0.3616287114309134
# Iteration number 89 complete
# Objective Value: 0.36201865391329663
# Iteration number 90 complete
# Objective Value: 0.36215423054996165
# Iteration number 91 complete
# Objective Value: 0.36233171468674824
# Iteration number 92 complete
# Objective Value: 0.362804414429114
# Iteration number 93 complete
# Objective Value: 0.3628380597700655
# Iteration number 94 complete
# Objective Value: 0.36295636433771755
# Iteration number 95 complete
# Objective Value: 0.36302147299105253
# Iteration number 96 complete
# Objective Value: 0.36316149374559126
# Iteration number 97 complete
# Objective Value: 0.3634070216050501
# Iteration number 98 complete
# Objective Value: 0.36388762503435035
# Iteration number 99 complete
# Objective Value: 0.3641420142072629
# Iteration number 100 complete
# Objective Value: 0.3646456308860602
# Iteration number 101 complete
# Objective Value: 0.36625386757637624
# Iteration number 102 complete
# Objective Value: 0.3663140364227293
# Iteration number 103 complete
# Objective Value: 0.36647093788663687
# Iteration number 104 complete
# Objective Value: 0.366845986612263
# Iteration number 105 complete
# Objective Value: 0.3671147006009549
# Iteration number 106 complete
# Objective Value: 0.3675325326693674
# Iteration number 107 complete
# Objective Value: 0.3675629439719132
# Iteration number 108 complete
# Objective Value: 0.36775085659696694
# Iteration number 109 complete
# Objective Value: 0.36824613475431195
# Iteration number 110 complete
# Objective Value: 0.36828599032221226
# Iteration number 111 complete
# Objective Value: 0.36839134200749113
# Iteration number 112 complete
# Objective Value: 0.3687659078000652
# Iteration number 113 complete
# Objective Value: 0.3687665998802734
# Iteration number 114 complete
# Objective Value: 0.36888699154376964
# Iteration number 115 complete
# Objective Value: 0.36895588888596104
# Iteration number 116 complete
# Objective Value: 0.3690657759993988
# Iteration number 117 complete
# Objective Value: 0.3691073888924163
# Iteration number 118 complete
# Objective Value: 0.3691772449648392
# Iteration number 119 complete
# Objective Value: 0.36966439006143337
# Iteration number 120 complete
# Objective Value: 0.36976128078613485
# Iteration number 121 complete
# Objective Value: 0.3698294469928749
# Iteration number 122 complete
# Objective Value: 0.369956844115631
# Iteration number 123 complete
# Objective Value: 0.3699568441156312
# Iteration number 124 complete
# Objective Value: 0.37002563074379297
# Iteration number 125 complete
# Objective Value: 0.3700256307437929
# Iteration number 126 complete
# Objective Value: 0.37007513594444796
# Iteration number 127 complete
# Objective Value: 0.37007513594444813
# Iteration number 128 complete
# Objective Value: 0.37008921110324805
# Iteration number 129 complete
# Objective Value: 0.3702348875427784
# Iteration number 130 complete
# Objective Value: 0.3703590103968988
# Iteration number 131 complete
# Objective Value: 0.37040361456349624
# Iteration number 132 complete
# Objective Value: 0.3704089664838805
# Iteration number 133 complete
# Objective Value: 0.37041673828017485
# Iteration number 134 complete
# Objective Value: 0.3705224965046526
# Iteration number 135 complete
# Objective Value: 0.3705224965046526
# Iteration number 136 complete
# Objective Value: 0.37052249650465263
# Iteration number 137 complete
# Objective Value: 0.3705224965046525
# Iteration number 138 complete
# Objective Value: 0.3705224965046525
# Iteration number 139 complete
# Objective Value: 0.3705224965046527
# Iteration number 140 complete
# Objective Value: 0.3705664518389992
# Iteration number 141 complete
# Objective Value: 0.37057041327119616
# Iteration number 142 complete
# Objective Value: 0.3706925929118648
# Iteration number 143 complete
# Objective Value: 0.3707035264876733
# Iteration number 144 complete
# Objective Value: 0.3707116134309157
# Iteration number 145 complete
# Objective Value: 0.3708806398848609
# Iteration number 146 complete
# Objective Value: 0.370880639884861
# Iteration number 147 complete
# Objective Value: 0.3709220021294665
# Iteration number 148 complete
# Objective Value: 0.3710523177309279
# Iteration number 149 complete
# Objective Value: 0.37105231773092806
# Iteration number 150 complete
# Objective Value: 0.37108546704433104
# Iteration number 151 complete
# Objective Value: 0.3710854670443313
